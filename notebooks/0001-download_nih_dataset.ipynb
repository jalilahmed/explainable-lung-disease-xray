# %%
# Imports
import kagglehub
import os

# %%
os.environ['KAGGLEHUB_CACHE'] = '/mnt/n4i_ds423/Employee_Folder/Jalil_Ahmed/NIH_Chest_Xray_Dataset'

# %%
path = kagglehub.dataset_download("nih-chest-xrays/data")
# Out:
# ...
# 100%|██████████| 42.0G/42.0G [25:05<00:00, 30.0MB/s]
# Extracting files...

# %%
path
# Out:
# '/mnt/n4i_ds423/Employee_Folder/Jalil_Ahmed/NIH_Chest_Xray_Dataset/datasets/nih-chest-xrays/data/versions/3'
